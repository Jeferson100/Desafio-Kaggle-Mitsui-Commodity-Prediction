# %% [markdown]
# # Importacao bibliotecas

# %%
import pandas as pd
import os

# %%
cwd = os.getcwd()
diretorio_data = os.path.join(os.path.dirname(cwd), "data")
diretorio_data
# Out:
# 'c:\\Users\\jefer\\Documents\\Ciencia-de-dados\\competicao_Kaggle\\Desafio-Kaggle-Mitsui-Commodity-Prediction\\data'

# %% [markdown]
# # Importacao dos dados

# %%
train = pd.read_csv(diretorio_data + "/train.csv")
train.head()
# Out:
#    date_id  LME_AH_Close  LME_CA_Close  LME_PB_Close  LME_ZS_Close  \
# 0        0        2264.5        7205.0        2570.0        3349.0
# 1        1        2228.0        7147.0        2579.0        3327.0
# 2        2        2250.0        7188.5        2587.0        3362.0
# 3        3        2202.5        7121.0        2540.0        3354.0
# 4        4        2175.0        7125.0        2604.0        3386.0
#
#    JPX_Gold_Mini_Futures_Open  JPX_Gold_Rolling-Spot_Futures_Open  \
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# 2                      4684.0                              4691.0
# 3                      4728.0                              4737.0
# 4                         NaN                                 NaN
#
#    JPX_Gold_Standard_Futures_Open  JPX_Platinum_Mini_Futures_Open  \
# 0                             NaN                             NaN
# ...

# %%
test = pd.read_csv(diretorio_data + "/test.csv")
test.head()
# Out:
#    date_id  LME_AH_Close  LME_CA_Close  LME_PB_Close  LME_ZS_Close  \
# 0     1827        2684.5        9190.0        1967.0        2942.0
# 1     1828        2691.5        9275.0        1985.0        2963.5
# 2     1829        2646.0        9284.5        1971.0        2914.0
# 3     1830        2634.0        9223.5        1967.0        2900.0
# 4     1831        2623.5        9232.0        1949.0        2846.5
#
#    JPX_Gold_Mini_Futures_Open  JPX_Gold_Rolling-Spot_Futures_Open  \
# 0                     13623.0                             13920.0
# 1                     13640.0                             13922.0
# 2                     13634.0                             13923.0
# 3                     13681.5                             13962.0
# 4                     13849.5                             14141.0
#
#    JPX_Gold_Standard_Futures_Open  JPX_Platinum_Mini_Futures_Open  \
# 0                         13618.0                          4696.0
# ...

# %%
train_label = pd.read_csv(diretorio_data + "/train_labels.csv")
train_label.head()
# Out:
#    date_id  target_0  target_1  target_2  target_3  target_4  target_5  \
# 0        0  0.005948 -0.002851 -0.004675 -0.000639       NaN       NaN
# 1        1  0.005783 -0.024118 -0.007052 -0.018955 -0.031852 -0.019452
# 2        2  0.001048  0.023836 -0.008934 -0.022060       NaN       NaN
# 3        3  0.001700 -0.024618  0.011943  0.004778       NaN       NaN
# 4        4 -0.003272  0.005234  0.006856  0.013312  0.023953  0.010681
#
#    target_6  target_7  target_8  ...  target_414  target_415  target_416  \
# 0 -0.006729  0.006066       NaN  ...         NaN    0.021239   -0.005595
# 1  0.003002 -0.006876 -0.002042  ...    0.003377    0.021372   -0.001517
# 2  0.037449  0.007658       NaN  ...   -0.006712    0.009308    0.001857
# 3 -0.012519 -0.016896       NaN  ...         NaN    0.036880   -0.015189
# 4 -0.011649  0.002019  0.003897  ...         NaN    0.004937         NaN
#
#    target_417  target_418  target_419  target_420  target_421  target_422  \
# ...
